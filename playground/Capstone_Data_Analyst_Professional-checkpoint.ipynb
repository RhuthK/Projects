# %% [markdown]
# <h1> Roles and Responsibilities </h1>
# <h3>- Role: Associate Data Analyst at Technology Consulting Organization </h3>
# <h3>- Responsibilities: </h3>
# <ul>
#     <li>Analyze data and find impactful insights</li>
#     <li>Discover the current and future trends technological trends using Stack Overflow Developer Survey dataset. </li>
#     These insights will play a key role in making strategic and business decisions.
# </ul>
# <h1>Project Objectives: </h1>
# <ul>
#     <li>Analyze data to answer key questions about the use of technology such as trends in Programming Languages, Databases, Platform, Frameworks, preffered technologies used in Industry by professionals.</li>
#     <li> Find insighst about the emerging patterns and shifts in technology landscape</li>
#     <li>Present findings to stakeholder for informed decision making</li>
# </ul>
# <h1>Tools and software used:</h1> SQL, Python, Jupyter Notebook (basic visualization), Google Looker Studio (Dashboard), Microsoft Powerpoint (presentation)
# <h1>Dataset Used: Stack Overflow Developer Survey </h1>
# <ul>
#     <li>Includes repsonsed from developers globally </li>
#     <li>Details about: <ul><li>Technology currently in use</li><li>Technology developer plan to use in future</li></ul>
#     <li>Includes Filtered and Preprocessed data</li></li></li>
# </ul>

# %% [markdown]
# <h1><b>Part 1:  Data Collection and Data Wrangling<b></b></h1>
# <h3>Data Collection: </h3>
# <ul>
#     <li>Using API Access </li>
#     <li>Using Web Scraping Techniques</li>
# </ul>
# <h3>Data Wrangling: </h3>
# <ul>
#     <li>Handling Duplicates </li>
#     <li>Identifying and Addressing Missing values</li>
#     <li>Normalizing data </li>
# </ul>
# <b>This step will ensure that the data is collected and ready for further analysis.</b>

# %%
# This code block will access the data through URL and then save it in excel file for futher use

# %% [markdown]
# <h1>Part 2: Exploratory Data Analysis (EDA)</h1>
#
# <ul>
#     <li>Examine the distributrion of responses  </li>
#     <li>Identify patterns in developer preferences.</li>
#     <li>Visualize using histogram and distribution plots</li>
#     <li>Find and handle outliers that may skew the data </li>
#     <li>Explore correlation bewteen features in the dataset</li>
# </ul>

# %% [markdown]
# <h1>Part 3: Data Visualization</h1>
# From the previous step we have a clear understanding of the relationship between features and outliers have been handled. In this step we will visualize the data to make the findings visually appealing and easy to interpret.
#
# <ul>Create Visualizations (such as):
#     <li>Histograms </li>
#     <li>Scatter plots </li>
#     <li>Pie Charts </li>
#     <li>Bar Charts </li>
# </ul>

# %% [markdown]
# <h1>Part 4: Dashboard</h1>
# Following the previous visualizations, in this step we will build an interactive dashboard using Google Looker Studio
#
# <p>Dashboard will be divided in 3 parts: </p>
# <ul>
#     <li>Current technology usage dashboard  </li>
#     <li>Future technology trends dashboard </li>
#     <li>Demographics Dashboard</li>
#
# </ul>

# %% [markdown]
# <h1>Part 5: Powerpoint Presentation</h1>
# <ul>
#     <li>Here we will deliver a well-strutured report. </li>
#     <li>This will help in making lasting impact through decision making </li>
# </ul>

# %% [markdown]
# <h1>Conclusion</h1>
